# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN',
'londON_StockhOlm',

'Budapest_PaRis', 'Brussels_londOn'],
'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
'12. Air France', '"Swiss Air"']})

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %% [markdown]
# ##Question1

# %%
df['FlightNumber'][1]=10055
# Out:
# c:\users\samridhi\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df['FlightNumber'][3]=10075
# Out:
# c:\users\samridhi\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis       10075.0          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df.dtypes
# Out:
# From_To          object
# FlightNumber    float64
# RecentDelays     object
# Airline          object
# dtype: object

# %%
df.astype({'FlightNumber':'int32'}).dtypes
# Out:
# From_To         object
# FlightNumber     int32
# RecentDelays    object
# Airline         object
# dtype: object

# %% [markdown]
# ##Question2

# %%
df2=df.copy(deep=True)

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis       10075.0          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df2
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis       10075.0          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df2[['From','To']]=df2.From_To.str.split("_",expand=True)

# %%
df2
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis       10075.0          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"
#
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %% [markdown]
# ##Question3

# %%
for i in df2['From']:
    print(str.upper(i[0])+str.lower(i[1:]))
# Out:
# London
# Madrid
# London
# Budapest
# Brussels

# %%
df2['From']=df2['From'].apply(lambda x: str.upper(x[0])+str.lower(x[1:]))
df2['To']=df2['To'].apply(lambda x: str.upper(x[0])+str.lower(x[1:]))

# %%
df.drop(columns=['From_To'],inplace=True)

# %%
df
# Out:
#    FlightNumber  RecentDelays              Airline
# 0       10045.0      [23, 47]               KLM(!)
# 1       10055.0            []    <Air France> (12)
# 2       10065.0  [24, 43, 87]  (British Airways. )
# 3       10075.0          [13]       12. Air France
# 4       10085.0      [67, 32]          "Swiss Air"

# %%
df2
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis       10075.0          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"
#
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %%
pd.concat([df,df2],ignore_index=True)
# Out:
#    FlightNumber  RecentDelays              Airline           From_To  \
# 0       10045.0      [23, 47]               KLM(!)               NaN
# 1       10055.0            []    <Air France> (12)               NaN
# 2       10065.0  [24, 43, 87]  (British Airways. )               NaN
# 3       10075.0          [13]       12. Air France               NaN
# 4       10085.0      [67, 32]          "Swiss Air"               NaN
# 5       10045.0      [23, 47]               KLM(!)      LoNDon_paris
# 6       10055.0            []    <Air France> (12)      MAdrid_miLAN
# 7       10065.0  [24, 43, 87]  (British Airways. )  londON_StockhOlm
# 8       10075.0          [13]       12. Air France    Budapest_PaRis
# 9       10085.0      [67, 32]          "Swiss Air"   Brussels_londOn
#
#        From         To
# 0       NaN        NaN
# 1       NaN        NaN
# 2       NaN        NaN
# 3       NaN        NaN
# 4       NaN        NaN
# 5    London      Paris
# 6    Madrid      Milan
# ...

# %% [markdown]
# ##Question4

# %%
df2
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis       10075.0          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"
#
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %%
df3=pd.DataFrame(df['RecentDelays'].values.tolist())

# %%
df3
# Out:
#       0     1     2
# 0  23.0  47.0   NaN
# 1   NaN   NaN   NaN
# 2  24.0  43.0  87.0
# 3  13.0   NaN   NaN
# 4  67.0  32.0   NaN

# %%
df3.rename(columns={0:'Delay1',1:'Delay2',2:'Delay3'},inplace=True)

# %%
df3
# Out:
#    Delay1  Delay2  Delay3
# 0    23.0    47.0     NaN
# 1     NaN     NaN     NaN
# 2    24.0    43.0    87.0
# 3    13.0     NaN     NaN
# 4    67.0    32.0     NaN

# %%
df[['Delay1','Delay2','Delay3']]=df3[['Delay1','Delay2','Delay3']]

# %%
df
# Out:
#    FlightNumber  RecentDelays              Airline  Delay1  Delay2  Delay3
# 0       10045.0      [23, 47]               KLM(!)    23.0    47.0     NaN
# 1       10055.0            []    <Air France> (12)     NaN     NaN     NaN
# 2       10065.0  [24, 43, 87]  (British Airways. )    24.0    43.0    87.0
# 3       10075.0          [13]       12. Air France    13.0     NaN     NaN
# 4       10085.0      [67, 32]          "Swiss Air"    67.0    32.0     NaN

# %%
df.drop(columns='RecentDelays',axis=1,inplace=True)

# %%
df
# Out:
#    FlightNumber              Airline  Delay1  Delay2  Delay3
# 0       10045.0               KLM(!)    23.0    47.0     NaN
# 1       10055.0    <Air France> (12)     NaN     NaN     NaN
# 2       10065.0  (British Airways. )    24.0    43.0    87.0
# 3       10075.0       12. Air France    13.0     NaN     NaN
# 4       10085.0          "Swiss Air"    67.0    32.0     NaN
